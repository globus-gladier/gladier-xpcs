# %%
## Globus client ID and portal ID
CLIENT_ID = "04dc20ba-d8e4-4a9a-9cc9-3ed3f3d49447" 
# INDEX_ID = "6871e83e-866b-41bc-8430-e3cf83b43bdc" # Old XPCS index.
INDEX_ID = "4428cfe6-611b-48db-81b2-167a7d9710ea"
ENDPOINT_ID = "74defd5b-5f61-42fc-bcc4-834c9f376a4f"  # Your endpoint ID
HTTPS_PATH = "https://g-f6125.fd635.8443.data.globus.org"
LOCAL_PATH = None #'/eagle/projects/XPCS-DATA-DYS' # Local path to save the files

## globus client setup
import globus_sdk

app = globus_sdk.UserApp(
    app_name="Notebook Main App",
    client_id=CLIENT_ID)

search_client = globus_sdk.SearchClient(app=app)
https_scope = f"https://auth.globus.org/scopes/{ENDPOINT_ID}/https"
app.add_scope_requirements({"{COLLECTION_ID}": https_scope})
token = app.get_authorizer(ENDPOINT_ID).access_token
##

## Query function
def make_query(query, field_name='dc.identifiers.identifier', filter_value='*',  limit=20):
    
    query_data = {
        'q':query,
        'limit': limit,
        'advanced' : True,
        'filters' : [
            {
                "type": "like",
                "field_name": field_name,
                "value": filter_value
            }
        ]
    }
    print(query_data)
    response = search_client.post_search(
        index_id=INDEX_ID,
        data=query_data
        )
    print("Query results: " + str(response['total']))
    return response

# extra functions for plotting and searching
from metadata import parse_result_files
from metadata import extract_metadata_structure
from metadata import extract_entry_key_values

from remote import get_log_in_memory
from remote import get_result_file

from nb_plot import start_new_plot
from nb_plot import show_plot
from nb_plot import plot_hdf_overlay

# %%
test = make_query('', limit=1)
extract_metadata_structure(test,verbose=True)
extract_entry_key_values(test['gmeta'][0])
# Out:
# {'q': '', 'limit': 1, 'advanced': True, 'filters': [{'type': 'like', 'field_name': 'dc.identifiers.identifier', 'value': '*'}]}
# Query results: 24571
#
# === DC KEYS ===
# ['dc.creators.name',
#  'dc.dates.date',
#  'dc.dates.dateType',
#  'dc.formats',
#  'dc.identifiers.identifier',
#  'dc.identifiers.identifierType',
#  'dc.publicationYear',
#  'dc.publisher',
#  'dc.schemaVersion',
#  'dc.subjects',
#  'dc.titles.title',
#  'dc.types.resourceType',
#  'dc.types.resourceTypeGeneral',
#  'dc.version']
#
# === PROJECT METADATA KEYS ===
# ['project_metadata./entry/instrument.attenuator_1.attenuator_index',
#  'project_metadata./entry/instrument.attenuator_1.attenuator_transmission',
#  'project_metadata./entry/instrument.attenuator_2.attenuator_index',
#  'project_metadata./entry/instrument.attenuator_2.attenuator_transmission',
#  'project_metadata./entry/instrument.beam_stop.size',
#  'project_metadata./entry/instrument.beam_stop.x_position',
#  'project_metadata./entry/instrument.beam_stop.y_position',
#  'project_metadata./entry/instrument.bluesky.bluesky_plan',
#  'project_metadata./entry/instrument.bluesky.bluesky_plan_kwargs',
#  'project_metadata./entry/instrument.bluesky.bluesky_version',
#  'project_metadata./entry/instrument.bluesky.parent_folder',
#  'project_metadata./entry/instrument.bluesky.scan_id',
#  'project_metadata./entry/instrument.bluesky.spec_file',
#  'project_metadata./entry/instrument.datamanagement.workflow_kwargs',
#  'project_metadata./entry/instrument.datamanagement.workflow_name',
#  'project_metadata./entry/instrument.datamanagement.workflow_version',
#  'project_metadata./entry/instrument.detector_1.beam_center_position_x',
#  'project_metadata./entry/instrument.detector_1.beam_center_position_y',
#  'project_metadata./entry/instrument.detector_1.beam_center_x',
#  'project_metadata./entry/instrument.detector_1.beam_center_y',
#  'project_metadata./entry/instrument.detector_1.compression',
#  'project_metadata./entry/instrument.detector_1.count_time',
#  'project_metadata./entry/instrument.detector_1.detector_name',
#  'project_metadata./entry/instrument.detector_1.distance',
#  'project_metadata./entry/instrument.detector_1.frame_time',
#  'project_metadata./entry/instrument.detector_1.position_x',
#  'project_metadata./entry/instrument.detector_1.position_y',
#  'project_metadata./entry/instrument.detector_1.rotation_x',
#  'project_metadata./entry/instrument.detector_1.rotation_y',
#  'project_metadata./entry/instrument.detector_1.rotation_z',
#  'project_metadata./entry/instrument.detector_1.x_pixel_size',
#  'project_metadata./entry/instrument.detector_1.y_pixel_size',
#  'project_metadata./entry/instrument.incident_beam.extent',
#  'project_metadata./entry/instrument.incident_beam.incident_beam_intensity',
#  'project_metadata./entry/instrument.incident_beam.incident_energy',
#  'project_metadata./entry/instrument.incident_beam.incident_energy_spread',
#  'project_metadata./entry/instrument.incident_beam.incident_polarization_type',
#  'project_metadata./entry/instrument.incident_beam.ring_current',
#  'project_metadata./entry/instrument.incident_beam.transmitted_beam_intensity',
#  'project_metadata./entry/instrument.monochromator.energy',
#  'project_metadata./entry/instrument.monochromator.wavelength',
#  'project_metadata./entry/instrument.slits_1.horizontal_center',
#  'project_metadata./entry/instrument.slits_1.horizontal_gap',
#  'project_metadata./entry/instrument.slits_1.vertical_center',
#  'project_metadata./entry/instrument.slits_1.vertical_gap',
#  'project_metadata./entry/instrument.undulator_1.energy',
#  'project_metadata./entry/instrument.undulator_1.gap',
#  'project_metadata./entry/instrument.undulator_2.energy',
#  'project_metadata./entry/instrument.undulator_2.gap',
#  'project_metadata./entry/sample.full_description',
#  'project_metadata./entry/sample.position_rheo_x',
#  'project_metadata./entry/sample.position_rheo_y',
#  'project_metadata./entry/sample.position_rheo_z',
#  'project_metadata./entry/sample.position_x',
#  'project_metadata./entry/sample.position_y',
#  'project_metadata./entry/sample.position_z',
#  'project_metadata./entry/sample.qnw1_temperature',
#  'project_metadata./entry/sample.qnw1_temperature_set',
#  'project_metadata./entry/sample.qnw2_temperature',
#  'project_metadata./entry/sample.qnw2_temperature_set',
#  'project_metadata./entry/sample.qnw3_temperature',
#  'project_metadata./entry/sample.qnw3_temperature_set',
#  'project_metadata./entry/sample.qnw_lakeshore',
#  'project_metadata./entry/sample.rheometer_shear_rate',
#  'project_metadata./entry/sample.rheometer_temperature',
#  'project_metadata./entry/sample.short_description',
#  'project_metadata./entry/user.cycle',
#  'project_metadata./entry/user.email',
#  'project_metadata./entry/user.institution',
#  'project_metadata./entry/user.name',
#  'project_metadata./entry/user.proposal_id',
#  'project_metadata./xpcs/multitau/config.analysis_type',
#  'project_metadata./xpcs/multitau/config.avg_frame',
#  'project_metadata./xpcs/multitau/config.begin_frame',
#  'project_metadata./xpcs/multitau/config.end_frame',
#  'project_metadata./xpcs/multitau/config.gpu_id',
#  'project_metadata./xpcs/multitau/config.output',
#  'project_metadata./xpcs/multitau/config.overwrite',
#  'project_metadata./xpcs/multitau/config.qmap',
#  'project_metadata./xpcs/multitau/config.raw',
#  'project_metadata./xpcs/multitau/config.save_G2',
#  'project_metadata./xpcs/multitau/config.smooth',
#  'project_metadata./xpcs/multitau/config.stride_frame',
#  'project_metadata./xpcs/multitau/config.verbose',
#  'project_metadata.analysis_type',
#  'project_metadata.cycle',
#  'project_metadata.experiment',
#  'project_metadata.facility',
#  'project_metadata.organization',
#  'project_metadata.plot_time',
#  'project_metadata.source_files.qmap',
#  'project_metadata.source_files.raw',
#  'project_metadata.start_time',
#  'project_metadata.tools.device',
#  'project_metadata.tools.execution_time_seconds',
#  'project_metadata.tools.name',
#  'project_metadata.tools.source',
#  'project_metadata.tools.tool_version']
#
# === FILE KEYS ===
# ['files.filename',
#  'files.https_url',
#  'files.length',
#  'files.mime_type',
#  'files.sha256',
#  'files.sha512',
#  'files.url']
#
# === ALL VALID SEARCH KEYS ===
# ['dc.creators.name',
#  'dc.dates.date',
#  'dc.dates.dateType',
#  'dc.formats',
#  'dc.identifiers.identifier',
#  'dc.identifiers.identifierType',
#  'dc.publicationYear',
#  'dc.publisher',
#  'dc.schemaVersion',
#  'dc.subjects',
#  'dc.titles.title',
#  'dc.types.resourceType',
#  'dc.types.resourceTypeGeneral',
#  'dc.version',
#  'files.filename',
#  'files.https_url',
#  'files.length',
#  'files.mime_type',
#  'files.sha256',
#  'files.sha512',
#  'files.url',
#  'project_metadata./entry/instrument.attenuator_1.attenuator_index',
#  'project_metadata./entry/instrument.attenuator_1.attenuator_transmission',
#  'project_metadata./entry/instrument.attenuator_2.attenuator_index',
#  'project_metadata./entry/instrument.attenuator_2.attenuator_transmission',
#  'project_metadata./entry/instrument.beam_stop.size',
#  'project_metadata./entry/instrument.beam_stop.x_position',
#  'project_metadata./entry/instrument.beam_stop.y_position',
#  'project_metadata./entry/instrument.bluesky.bluesky_plan',
#  'project_metadata./entry/instrument.bluesky.bluesky_plan_kwargs',
#  'project_metadata./entry/instrument.bluesky.bluesky_version',
#  'project_metadata./entry/instrument.bluesky.parent_folder',
#  'project_metadata./entry/instrument.bluesky.scan_id',
#  'project_metadata./entry/instrument.bluesky.spec_file',
#  'project_metadata./entry/instrument.datamanagement.workflow_kwargs',
#  'project_metadata./entry/instrument.datamanagement.workflow_name',
#  'project_metadata./entry/instrument.datamanagement.workflow_version',
#  'project_metadata./entry/instrument.detector_1.beam_center_position_x',
#  'project_metadata./entry/instrument.detector_1.beam_center_position_y',
#  'project_metadata./entry/instrument.detector_1.beam_center_x',
#  'project_metadata./entry/instrument.detector_1.beam_center_y',
#  'project_metadata./entry/instrument.detector_1.compression',
#  'project_metadata./entry/instrument.detector_1.count_time',
#  'project_metadata./entry/instrument.detector_1.detector_name',
#  'project_metadata./entry/instrument.detector_1.distance',
#  'project_metadata./entry/instrument.detector_1.frame_time',
#  'project_metadata./entry/instrument.detector_1.position_x',
#  'project_metadata./entry/instrument.detector_1.position_y',
#  'project_metadata./entry/instrument.detector_1.rotation_x',
#  'project_metadata./entry/instrument.detector_1.rotation_y',
#  'project_metadata./entry/instrument.detector_1.rotation_z',
#  'project_metadata./entry/instrument.detector_1.x_pixel_size',
#  'project_metadata./entry/instrument.detector_1.y_pixel_size',
#  'project_metadata./entry/instrument.incident_beam.extent',
#  'project_metadata./entry/instrument.incident_beam.incident_beam_intensity',
#  'project_metadata./entry/instrument.incident_beam.incident_energy',
#  'project_metadata./entry/instrument.incident_beam.incident_energy_spread',
#  'project_metadata./entry/instrument.incident_beam.incident_polarization_type',
#  'project_metadata./entry/instrument.incident_beam.ring_current',
#  'project_metadata./entry/instrument.incident_beam.transmitted_beam_intensity',
#  'project_metadata./entry/instrument.monochromator.energy',
#  'project_metadata./entry/instrument.monochromator.wavelength',
#  'project_metadata./entry/instrument.slits_1.horizontal_center',
#  'project_metadata./entry/instrument.slits_1.horizontal_gap',
#  'project_metadata./entry/instrument.slits_1.vertical_center',
#  'project_metadata./entry/instrument.slits_1.vertical_gap',
#  'project_metadata./entry/instrument.undulator_1.energy',
#  'project_metadata./entry/instrument.undulator_1.gap',
#  'project_metadata./entry/instrument.undulator_2.energy',
#  'project_metadata./entry/instrument.undulator_2.gap',
#  'project_metadata./entry/sample.full_description',
#  'project_metadata./entry/sample.position_rheo_x',
#  'project_metadata./entry/sample.position_rheo_y',
#  'project_metadata./entry/sample.position_rheo_z',
#  'project_metadata./entry/sample.position_x',
#  'project_metadata./entry/sample.position_y',
#  'project_metadata./entry/sample.position_z',
#  'project_metadata./entry/sample.qnw1_temperature',
#  'project_metadata./entry/sample.qnw1_temperature_set',
#  'project_metadata./entry/sample.qnw2_temperature',
#  'project_metadata./entry/sample.qnw2_temperature_set',
#  'project_metadata./entry/sample.qnw3_temperature',
#  'project_metadata./entry/sample.qnw3_temperature_set',
#  'project_metadata./entry/sample.qnw_lakeshore',
#  'project_metadata./entry/sample.rheometer_shear_rate',
#  'project_metadata./entry/sample.rheometer_temperature',
#  'project_metadata./entry/sample.short_description',
#  'project_metadata./entry/user.cycle',
#  'project_metadata./entry/user.email',
#  'project_metadata./entry/user.institution',
#  'project_metadata./entry/user.name',
#  'project_metadata./entry/user.proposal_id',
#  'project_metadata./xpcs/multitau/config.analysis_type',
#  'project_metadata./xpcs/multitau/config.avg_frame',
#  'project_metadata./xpcs/multitau/config.begin_frame',
#  'project_metadata./xpcs/multitau/config.end_frame',
#  'project_metadata./xpcs/multitau/config.gpu_id',
#  'project_metadata./xpcs/multitau/config.output',
#  'project_metadata./xpcs/multitau/config.overwrite',
#  'project_metadata./xpcs/multitau/config.qmap',
#  'project_metadata./xpcs/multitau/config.raw',
#  'project_metadata./xpcs/multitau/config.save_G2',
#  'project_metadata./xpcs/multitau/config.smooth',
#  'project_metadata./xpcs/multitau/config.stride_frame',
#  'project_metadata./xpcs/multitau/config.verbose',
#  'project_metadata.analysis_type',
#  'project_metadata.cycle',
#  'project_metadata.experiment',
#  'project_metadata.facility',
#  'project_metadata.organization',
#  'project_metadata.plot_time',
#  'project_metadata.source_files.qmap',
#  'project_metadata.source_files.raw',
#  'project_metadata.start_time',
#  'project_metadata.tools.device',
#  'project_metadata.tools.execution_time_seconds',
#  'project_metadata.tools.name',
#  'project_metadata.tools.source',
#  'project_metadata.tools.tool_version']
# [('dc.types.resourceTypeGeneral', 'Dataset'),
#  ('dc.types.resourceType', 'Dataset'),
#  ('dc.formats.0', 'application/json'),
#  ('dc.formats.1', 'text/x-log'),
#  ('dc.formats.2', 'image/png'),
#  ('dc.formats.3', 'application/x-hdf'),
#  ('dc.schemaVersion', 'http://datacite.org/schema/kernel-4'),
#  ('dc.creators.0.name', ''),
#  ('dc.identifiers.0.identifier',
#   'globus://74defd5b-5f61-42fc-bcc4-834c9f376a4f/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001'),
#  ('dc.identifiers.0.identifierType', 'GlobusSearchSubject'),
#  ('dc.publicationYear', '2025'),
#  ('dc.publisher', ''),
#  ('dc.dates.0.date', '2025-06-07T01:11:37.299783Z'),
#  ('dc.dates.0.dateType', 'Created'),
#  ('dc.titles.0.title', 'volfrac114985_10nm-frac_a0050_f100000_r00001'),
#  ('dc.version', '1'),
#  ('project_metadata./entry/user.name', 'John Doe'),
#  ('project_metadata./entry/user.institution', 'Institution Name'),
#  ('project_metadata./entry/user.proposal_id', 'none'),
#  ('project_metadata./entry/user.cycle', '2025-1'),
#  ('project_metadata./entry/user.email', 'JohnDoe@mail.edu'),
#  ('project_metadata.source_files.raw.0',
#   '/8IDI/2025-1/milliron202503/data/volfrac114985_10nm-frac_a0050_f100000_r00001'),
#  ('project_metadata.source_files.qmap.0',
#   '/8IDI/2025-1/milliron202503/data/rigaku_qmap_Sq360_Dq36_Lin_0501.hdf'),
#  ('project_metadata.analysis_type.0', 'Multitau'),
#  ('project_metadata.cycle', '2025-1'),
#  ('project_metadata.plot_time', '2025-06-07 01:11:33'),
#  ('project_metadata.tools.0.name', 'boost_corr'),
#  ('project_metadata.tools.0.source', 'https://pypi.org/project/boost_corr/'),
#  ('project_metadata.tools.0.tool_version', '0.1.5.dev108+g70ed7fd'),
#  ('project_metadata.tools.0.device', 'gpu'),
#  ('project_metadata.tools.0.execution_time_seconds', 47.88),
#  ('project_metadata.tools.1.name', 'xpcs_webplot'),
#  ('project_metadata.tools.1.source', 'https://github.com/AZjk/xpcs_webplot'),
#  ('project_metadata.tools.1.tool_version', '0.0.1'),
#  ('project_metadata.tools.1.device', 'cpu'),
#  ('project_metadata.tools.1.execution_time_seconds', 15.36),
#  ('project_metadata./entry/instrument.incident_beam.extent', 1e-06),
#  ('project_metadata./entry/instrument.incident_beam.incident_polarization_type',
#   'linear_horizontal'),
#  ('project_metadata./entry/instrument.incident_beam.incident_beam_intensity',
#   4.547426095626841),
#  ('project_metadata./entry/instrument.incident_beam.incident_energy_spread',
#   0.0001),
#  ('project_metadata./entry/instrument.incident_beam.ring_current', 0.0),
#  ('project_metadata./entry/instrument.incident_beam.transmitted_beam_intensity',
#   0.0001),
#  ('project_metadata./entry/instrument.incident_beam.incident_energy',
#   12.313024564529496),
#  ('project_metadata./entry/instrument.monochromator.wavelength', 1.0),
#  ('project_metadata./entry/instrument.monochromator.energy', 1.0),
#  ('project_metadata./entry/instrument.beam_stop.size', 1.0),
#  ('project_metadata./entry/instrument.beam_stop.x_position', 1.0),
#  ('project_metadata./entry/instrument.beam_stop.y_position', 1.0),
#  ('project_metadata./entry/instrument.slits_1.vertical_center', 0.0),
#  ('project_metadata./entry/instrument.slits_1.vertical_gap', 1.0),
#  ('project_metadata./entry/instrument.slits_1.horizontal_center', 0.0),
#  ('project_metadata./entry/instrument.slits_1.horizontal_gap', 1.0),
#  ('project_metadata./entry/instrument.datamanagement.workflow_version',
#   '0.0.1'),
#  ('project_metadata./entry/instrument.datamanagement.workflow_name',
#   'boost_corr workflow'),
#  ('project_metadata./entry/instrument.datamanagement.workflow_kwargs',
#   '{"key": "value"}'),
#  ('project_metadata./entry/instrument.bluesky.spec_file',
#   'milliron202503.dat'),
#  ('project_metadata./entry/instrument.bluesky.bluesky_plan', 'mesh_scan'),
#  ('project_metadata./entry/instrument.bluesky.bluesky_version', '1.0.0'),
#  ('project_metadata./entry/instrument.bluesky.parent_folder',
#   '/gdata/dm/8IDI/2025-1/milliron202503/data/'),
#  ('project_metadata./entry/instrument.bluesky.bluesky_plan_kwargs',
#   'mesh_scan_sample_kwargs'),
#  ('project_metadata./entry/instrument.bluesky.scan_id', 1),
#  ('project_metadata./entry/instrument.attenuator_2.attenuator_transmission',
#   0.019859774388670245),
#  ('project_metadata./entry/instrument.attenuator_2.attenuator_index', 19),
#  ('project_metadata./entry/instrument.detector_1.distance', 9.030036130000001),
#  ('project_metadata./entry/instrument.detector_1.rotation_x', 0.0),
#  ('project_metadata./entry/instrument.detector_1.y_pixel_size', 7.5e-05),
#  ('project_metadata./entry/instrument.detector_1.rotation_z', 0.0),
#  ('project_metadata./entry/instrument.detector_1.rotation_y', 0.0),
#  ('project_metadata./entry/instrument.detector_1.detector_name', 'rigaku3M'),
#  ('project_metadata./entry/instrument.detector_1.beam_center_position_x',
#   774.0),
#  ('project_metadata./entry/instrument.detector_1.count_time', 2e-05),
#  ('project_metadata./entry/instrument.detector_1.beam_center_position_y',
#   809.5),
#  ('project_metadata./entry/instrument.detector_1.position_x',
#   -229.86453399999994),
#  ('project_metadata./entry/instrument.detector_1.position_y', 170.000003),
#  ('project_metadata./entry/instrument.detector_1.x_pixel_size', 7.5e-05),
#  ('project_metadata./entry/instrument.detector_1.compression', 'bslz4'),
#  ('project_metadata./entry/instrument.detector_1.beam_center_y', 809.5),
#  ('project_metadata./entry/instrument.detector_1.beam_center_x', 774.0),
#  ('project_metadata./entry/instrument.detector_1.frame_time', 2e-05),
#  ('project_metadata./entry/instrument.undulator_2.gap', 1.0),
#  ('project_metadata./entry/instrument.undulator_2.energy', 1.0),
#  ('project_metadata./entry/instrument.attenuator_1.attenuator_transmission',
#   1.0),
#  ('project_metadata./entry/instrument.attenuator_1.attenuator_index', 19),
#  ('project_metadata./entry/instrument.undulator_1.gap', 1.0),
#  ('project_metadata./entry/instrument.undulator_1.energy', 1.0),
#  ('project_metadata.start_time', '2025-03-17 02:40:24.735520'),
#  ('project_metadata./entry/sample.position_rheo_z', 0.016826),
#  ('project_metadata./entry/sample.position_rheo_y', 344.526),
#  ('project_metadata./entry/sample.short_description',
#   'Short sample description'),
#  ('project_metadata./entry/sample.qnw1_temperature_set', 26.0),
#  ('project_metadata./entry/sample.qnw2_temperature_set', 25.0),
#  ('project_metadata./entry/sample.rheometer_temperature', 1.0),
#  ('project_metadata./entry/sample.qnw3_temperature_set', 25.0),
#  ('project_metadata./entry/sample.position_x', 195.10000274658205),
#  ('project_metadata./entry/sample.full_description',
#   'Full sample description'),
#  ('project_metadata./entry/sample.position_y', 20.000000915527345),
#  ('project_metadata./entry/sample.position_z', 0.04727081298828125),
#  ('project_metadata./entry/sample.qnw3_temperature', 24.99),
#  ('project_metadata./entry/sample.rheometer_shear_rate', 1.0),
#  ('project_metadata./entry/sample.qnw1_temperature', 26.0),
#  ('project_metadata./entry/sample.qnw_lakeshore', 302.265),
#  ('project_metadata./entry/sample.position_rheo_x', 0.38999999999999996),
#  ('project_metadata./entry/sample.qnw2_temperature', 24.99),
#  ('project_metadata.experiment', 'milliron'),
#  ('project_metadata./xpcs/multitau/config.analysis_type', 'multitau'),
#  ('project_metadata./xpcs/multitau/config.avg_frame', 1),
#  ('project_metadata./xpcs/multitau/config.raw',
#   '/eagle/APSDataProcessing/aps8idi/xpcs_staging/milliron202503/volfrac114985_10nm-frac_a0050_f100000_r00001/input/volfrac114985_10nm-frac_a0050_f100000_r00001.bin.000'),
#  ('project_metadata./xpcs/multitau/config.stride_frame', 1),
#  ('project_metadata./xpcs/multitau/config.gpu_id', 0),
#  ('project_metadata./xpcs/multitau/config.save_G2', False),
#  ('project_metadata./xpcs/multitau/config.verbose', True),
#  ('project_metadata./xpcs/multitau/config.output',
#   '/eagle/APSDataProcessing/aps8idi/xpcs_staging/milliron202503/volfrac114985_10nm-frac_a0050_f100000_r00001/output/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001'),
#  ('project_metadata./xpcs/multitau/config.begin_frame', 0),
#  ('project_metadata./xpcs/multitau/config.end_frame', -1),
#  ('project_metadata./xpcs/multitau/config.overwrite', True),
#  ('project_metadata./xpcs/multitau/config.qmap',
#   '/eagle/APSDataProcessing/aps8idi/xpcs_staging/milliron202503/volfrac114985_10nm-frac_a0050_f100000_r00001/qmap/rigaku_qmap_Sq360_Dq36_Lin_0501.hdf'),
#  ('project_metadata./xpcs/multitau/config.smooth', 'sqmap'),
#  ('project_metadata.organization', 'ALCF'),
#  ('project_metadata.facility', 'Polaris'),
#  ('files.filename',
#   'volfrac114985_10nm-frac_a0050_f100000_r00001_results.hdf'),
#  ('files.https_url',
#   'https://g-f6125.fd635.8443.data.globus.org/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/volfrac114985_10nm-frac_a0050_f100000_r00001_results.hdf'),
#  ('files.sha256',
#   '39742efbfd7fedbe78a0ba8477f4af165851af0bce043a7431e163ea1c544fcd'),
#  ('files.mime_type', 'application/x-hdf'),
#  ('files.length', 4080856),
#  ('files.sha512',
#   '4d5cef99c802788077452be1ceea48b6ab7e9750a29abb3472cad1495fa4e6451e4594d9a57c8c4ad6d4c68634ce816ba0efe3c8bf07b93038d7c012e914bd0d'),
#  ('files.url',
#   'globus://74defd5b-5f61-42fc-bcc4-834c9f376a4f/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/volfrac114985_10nm-frac_a0050_f100000_r00001_results.hdf'),
#  ('files.filename', 'boost_corr.log'),
#  ('files.https_url',
#   'https://g-f6125.fd635.8443.data.globus.org/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/boost_corr.log'),
#  ('files.sha256',
#   'efa409ab3b6593b065181fdc22c28124e3c901785b104b3086db79a8604184f7'),
#  ('files.mime_type', 'text/x-log'),
#  ('files.length', 16407),
#  ('files.sha512',
#   '5becd7e2456d6a535d3f36718e6462bbf7aa730f29e5ff20c80320ec6d261ed6adc8a7f98ee981b1269abb62d7db058c763f1e5979cbb86a056592b424e35236'),
#  ('files.url',
#   'globus://74defd5b-5f61-42fc-bcc4-834c9f376a4f/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/boost_corr.log'),
#  ('files.filename', 'metadata.json'),
#  ('files.https_url',
#   'https://g-f6125.fd635.8443.data.globus.org/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/metadata.json'),
#  ('files.sha256',
#   '952531760ce213c39a94ba4ddd60daa33f1bab69d14537e6be508167812801ae'),
#  ('files.mime_type', 'application/json'),
#  ('files.length', 5742),
#  ('files.sha512',
#   'cffb8b2bc4e9662c29329e3dd1be481fa58c96b92c72758e1d5f64dd170ea4ac9ea5aeed230f55eb35a6a5c4e589dcbbb810bd7030e7dece3add5b064f3ce97d'),
#  ('files.url',
#   'globus://74defd5b-5f61-42fc-bcc4-834c9f376a4f/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/metadata.json'),
#  ('files.filename',
#   'volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_045_053.png'),
#  ('files.https_url',
#   'https://g-f6125.fd635.8443.data.globus.org/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_045_053.png'),
#  ('files.sha256',
#   '747474fab58a4b111375b189d9a553e9a78c3384d4d29e91e963c310dc0e56b8'),
#  ('files.mime_type', 'image/png'),
#  ('files.length', 194606),
#  ('files.sha512',
#   '0b30e7a650f5daa8df085510df210765d0f1d66dc912f2a679ee48d9e0d9846a73bb427c62b74745cfc6786f996d70460f362eaa2c54181c6ddbfb6d50b4e0f8'),
#  ('files.url',
#   'globus://74defd5b-5f61-42fc-bcc4-834c9f376a4f/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_045_053.png'),
#  ('files.filename', 'total_intensity_vs_time.png'),
#  ('files.https_url',
#   'https://g-f6125.fd635.8443.data.globus.org/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/total_intensity_vs_time.png'),
#  ('files.sha256',
#   '747d4891546e7ccaf93bd335e8106c4ee34f71a3a9733d99940899abd9129ed6'),
#  ('files.mime_type', 'image/png'),
#  ('files.length', 224174),
#  ('files.sha512',
#   '827567211e1d388fdd79a00e4b795b0c545f86507628ffe20e97be9cdb49a566af7e23e0f5269245955069cfd1514e5faaa46bb075cc4d4b6de7f884f12bc24d'),
#  ('files.url',
#   'globus://74defd5b-5f61-42fc-bcc4-834c9f376a4f/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/total_intensity_vs_time.png'),
#  ('files.filename',
#   'volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_000_008.png'),
#  ('files.https_url',
#   'https://g-f6125.fd635.8443.data.globus.org/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_000_008.png'),
#  ('files.sha256',
#   'ab8192cee383c7615dfa67cd2b1bf3ac99ea4f3dc02a857b1ae42c693263d95d'),
#  ('files.mime_type', 'image/png'),
#  ('files.length', 129734),
#  ('files.sha512',
#   '8988c3988e2084ab13d99034974f431d8c032a75e732fb803dcacabf911a405cb0f934553e6896c40842d7822e83821838a5bd47f3c90dc835849501dcc05431'),
#  ('files.url',
#   'globus://74defd5b-5f61-42fc-bcc4-834c9f376a4f/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_000_008.png'),
#  ('files.filename',
#   'volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_072_080.png'),
#  ('files.https_url',
#   'https://g-f6125.fd635.8443.data.globus.org/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_072_080.png'),
#  ('files.sha256',
#   '6cb40c2cb2732be6a2b61e05707a99dcd03fb4d4a7d30fe2d13097f62816c0f3'),
#  ('files.mime_type', 'image/png'),
#  ('files.length', 176274),
#  ('files.sha512',
#   '1371f2dceba9a45eaf610775635bebe6b756022b67fdd1e5abf120130495b58b7b46f90275a34c37ab2bb99962133afe601c83726c97c20c15493791c0bf7544'),
#  ('files.url',
#   'globus://74defd5b-5f61-42fc-bcc4-834c9f376a4f/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_072_080.png'),
#  ('files.filename', 'scattering_pattern_log.png'),
#  ('files.https_url',
#   'https://g-f6125.fd635.8443.data.globus.org/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/scattering_pattern_log.png'),
#  ('files.sha256',
#   '4173c718710c4a12ba8ca3ce65848fb4e4d7c80be5ceb327fa4ab8fa5631e3bd'),
#  ('files.mime_type', 'image/png'),
#  ('files.length', 890381),
#  ('files.sha512',
#   '35ba90a061eb4269f6dafd3965edd8665c87c5a136d5524459cdabd06d022bfbd299bec760e9dc6f7f692860294032dd2fcf4ef708b85b06f6f3d74b778819d8'),
#  ('files.url',
#   'globus://74defd5b-5f61-42fc-bcc4-834c9f376a4f/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/scattering_pattern_log.png'),
#  ('files.filename',
#   'volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_018_026.png'),
#  ('files.https_url',
#   'https://g-f6125.fd635.8443.data.globus.org/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_018_026.png'),
#  ('files.sha256',
#   '6232a560a2c7e6a5b0b2e42ec2b62453cf2c32976adfd648d45d2de3a7c4b555'),
#  ('files.mime_type', 'image/png'),
#  ('files.length', 177899),
#  ('files.sha512',
#   '861c3f16ed975aa94a300e1170c01244bedf7768298d11b10e627756a3713f60646c8ae2da42350b4d492c39578b63399e752647116ab0a004c18809996d54ba'),
#  ('files.url',
#   'globus://74defd5b-5f61-42fc-bcc4-834c9f376a4f/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_018_026.png'),
#  ('files.filename',
#   'volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_009_017.png'),
#  ('files.https_url',
#   'https://g-f6125.fd635.8443.data.globus.org/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_009_017.png'),
#  ('files.sha256',
#   '65d4f42c04a5d62b28f839bc5a6f84df8b81bd94ccb178b4686a2fbfd64d03de'),
#  ('files.mime_type', 'image/png'),
#  ('files.length', 156781),
#  ('files.sha512',
#   '9253c910a54ab092a314eddfa6dd82e70ae7d16523af028ea94dbefaee5f5881c4ab7ba0f0b9469f386b39b7072f973b6f87828b9e9908b9d5a89aa8c1e5f1fd'),
#  ('files.url',
#   'globus://74defd5b-5f61-42fc-bcc4-834c9f376a4f/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_009_017.png'),
#  ('files.filename',
#   'volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_036_044.png'),
#  ('files.https_url',
#   'https://g-f6125.fd635.8443.data.globus.org/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_036_044.png'),
#  ('files.sha256',
#   'faa6cf2da00c9c44e65bfc9ac64aa07d84f147117a7c79e146d2f5047e137e8b'),
#  ('files.mime_type', 'image/png'),
#  ('files.length', 198667),
#  ('files.sha512',
#   'baba92018e5ed2158d2580b3e2d91425f7526f35d47a20ccb299fc7783916d55e66e974f67f50c42b2f93df04f39ae23d871cb059f64dbc8df37b6393c263334'),
#  ('files.url',
#   'globus://74defd5b-5f61-42fc-bcc4-834c9f376a4f/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_036_044.png'),
#  ('files.filename',
#   'volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_027_035.png'),
#  ('files.https_url',
#   'https://g-f6125.fd635.8443.data.globus.org/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_027_035.png'),
#  ('files.sha256',
#   'b52d190c7b035e7c049ece6b0e7ccb69ad78d23a65de67bd4171ea5605d80c33'),
#  ('files.mime_type', 'image/png'),
#  ('files.length', 197549),
#  ('files.sha512',
#   '14d506e251b2ccf018dcc985d1688295b0b916027c203d172c63313e3b87e933ad4a304ea25314f5370de0612939219b9504017657a4d77f7afe27f7200187a1'),
#  ('files.url',
#   'globus://74defd5b-5f61-42fc-bcc4-834c9f376a4f/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_027_035.png'),
#  ('files.filename',
#   'volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_054_062.png'),
#  ('files.https_url',
#   'https://g-f6125.fd635.8443.data.globus.org/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_054_062.png'),
#  ('files.sha256',
#   '4ceda0c3e6321adb9339448c2936dd87e7ce7d77845a467fa5ff51e520e8c048'),
#  ('files.mime_type', 'image/png'),
#  ('files.length', 190841),
#  ('files.sha512',
#   '3696d56567a1fedc2908bbf8d9def19c2dbd1a8a0bc3f6b5b36fe6dc389c5a7ff3813aeba60d3b49cbd4b67cb80291adfae2310038d30a2827578e5fdde5bf52'),
#  ('files.url',
#   'globus://74defd5b-5f61-42fc-bcc4-834c9f376a4f/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_054_062.png'),
#  ('files.filename',
#   'volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_063_071.png'),
#  ('files.https_url',
#   'https://g-f6125.fd635.8443.data.globus.org/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_063_071.png'),
#  ('files.sha256',
#   'fdcf027e478ba31422d221af48492e1cf16f09492cb424a77bf8786fa8eeb060'),
#  ('files.mime_type', 'image/png'),
#  ('files.length', 187226),
#  ('files.sha512',
#   'eb8a7ad0e9c5ab77a5f8a4890c9e8bcf7af7e9129ee431e88354eaf4099de5e39212bdcd1edf4a3450a3466d59e06a80c0f2c8d24a7cb20806c65c2bb926386b'),
#  ('files.url',
#   'globus://74defd5b-5f61-42fc-bcc4-834c9f376a4f/XPCSDATA/Automate/2025-1/milliron202503/rigaku_qmap_Sq360_Dq36_Lin_0501/volfrac114985_10nm-frac_a0050_f100000_r00001/resources/volfrac114985_10nm-frac_a0050_f100000_r00001_results/volfrac114985_10nm-frac_a0050_f100000_r00001_results_g2_corr_063_071.png')]
